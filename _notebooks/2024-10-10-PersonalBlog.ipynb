// %% [markdown]
// ---
// layout: post
// title: Personal Blog
// type: ccc
// toc: false
// courses: {csa: {week: 7}}
// comments: true
// ---

// %% [markdown]
// | **Assignment**             | **Points**    | **Grade** | **Evidence**                                                                                                 |
// |----------------------------|---------------|-----------|--------------------------------------------------------------------------------------------------------------|
// | Pull Request (Integration) | 2             | 1.8       | Merged critical feature branches into the main project, resolving conflicts and ensuring smooth integration. Included comprehensive comments on changes. ![image](https://github.com/user-attachments/assets/e7b11856-acda-4177-8480-bba9f600b0b9)  |
// | Relevancy Checklist (Peer) | 2             | 1.8       | Participated actively in peer reviews by creating and commenting on checklist issues. This contributed to refining project standards and ensuring relevance. ![image](https://github.com/user-attachments/assets/d86c820e-722a-428c-a016-301777eec7be)
// |
// | Lesson (Group)             | 1             | 0.93      | Collaborated effectively on a group lesson, focusing on key topics and breaking down complex concepts into simpler sections. Included interactive examples for better comprehension. ![image](https://github.com/user-attachments/assets/a66c8b93-f61b-4871-98f3-d04fe1390342) |
// | Homework, Popcorn Hacks    | 1 x 8         | 7.3       | Completed 8 hands-on coding exercises, demonstrating proficiency in core concepts. Provided solutions and explained code logic clearly. ![image](https://github.com/user-attachments/assets/3017f544-b985-49d6-a5dc-e766c53cf47e) |
// | Individual Contribution    | 1             | 0.91      | Worked independently on a programming task that extended the class project. Documented the process and published a detailed write-up on the assigned topic. [Link to Contribution](https://nighthawkcoders.github.io/portfolio_2025/csa/unit6_p3/6.4/) |
// | Personal Notebooks / Blogs | 1             | 0.91      | Created and maintained a personal blog documenting progress and key learnings. The posts serve as a reflective journal to track skill development over time. [Link to Blog](https://srinivasnampalli.github.io/SRINIVCSA/navigation/section/csa.html) |
// | **Total**                  | 11/12         |           |                                                                                                              |

// %% [markdown]
// | **Skill**                  | **Points**    | **Grade** | **Evidence**                                                                                     |
// |----------------------------|---------------|-----------|--------------------------------------------------------------------------------------------------|
// | Work Habits (Analytics)    |   1           |    0.91       |  Thoroughly analyzed project requirements and broke them down into manageable tasks. The team utilized analytics to track progress and adjust strategies as needed. ![image](https://github.com/user-attachments/assets/af0b13b2-b4eb-467f-a084-e35377a7676a)  |
// | Team Planning (Issue)      |   1           |    0.91       |  Developed an effective plan that addressed key project issues and delegated tasks to team members efficiently. Regular meetings ensured alignment on priorities and problem-solving. ![image](https://github.com/user-attachments/assets/2bdb2db5-dd2b-448a-be9a-35cab62e13f5)  |
// | Presentation Memories      |   1           |    1         |  Created a compelling presentation that effectively communicated project outcomes. Visual aids and cohesive storytelling were utilized to reinforce key messages. ![image](https://github.com/user-attachments/assets/7de22b3d-62d2-47c6-9ec0-017796440ad0)  |
// | Grading and Feedback       |   1           |    0.87      |  Provided constructive feedback during peer review sessions. Ensured that feedback was both detailed and actionable, leading to iterative improvements. ![image](https://github.com/user-attachments/assets/577a9deb-0067-4f67-96c5-7e43a7c5c022)  |
// | Beyond Perfunctory         |   1           |    0.93      |  Went above and beyond to create an impactful lesson plan that served as a model for future initiatives. The collaborative approach emphasized shared vision and excellence.  |
// | **Total**                  |   5           |             |                                                                                                  |

// %% [markdown]
// ### BASIC OVERVIEW OF CODE
// <div class="container">
//     <!-- Unit 3: Boolean Expressions and If Statements -->
//     <div class="unit-card">
//         <div class="unit-title">Unit 3: Boolean Expressions and If Statements</div>
//         <div class="unit-content">
//             This unit covers how to use boolean logic to make decisions in code using `if`, `else if`, and `else` statements.
//             <div class="code-snippet">
//                 <pre class="code">
// <code>int age = 18;
// if (age >= 18) {
//   System.out.println("You are an adult.");
// } else {
//   System.out.println("You are a minor.");
// }
// boolean isRaining = false;
// boolean hasUmbrella = true;
// if (isRaining && !hasUmbrella) {
//   System.out.println("Stay inside!");
// } else {
//   System.out.println("You can go out!");
// }
// </code>
//                 </pre>
//             </div>
//         </div>
//     </div>
//
//     <!-- Unit 4: Iteration -->
//     <div class="unit-card">
//         <div class="unit-title">Unit 4: Iteration</div>
//         <div class="unit-content">
//             Learn how to repeat tasks using loops. Covers `for`, `while`, and `do-while` loops.
//             <div class="code-snippet">
//                 <pre class="code">
// <code>for (int i = 0; i < 5; i++) {
//   System.out.println("Iteration: " + i);
// }
// int count = 1;
// while (count <= 5) {
//   System.out.println("Count: " + count);
//   count++;
// }
// int n = 0;
// do {
//   System.out.println("Number: " + n);
//   n++;
// } while (n < 3);
// </code>
//                 </pre>
//             </div>
//         </div>
//     </div>
//     <!-- Unit 6: Arrays -->
//     <div class="unit-card">
//         <div class="unit-title">Unit 6: Arrays</div>
//         <div class="unit-content">
//             Arrays are used to store multiple values in a single variable. This unit covers creating, accessing, and modifying arrays.
//             <div class="code-snippet">
//                 <pre class="code">
// <code>String[] colors = {"Red", "Green", "Blue"};
// for (int i = 0; i < colors.length; i++) {
//   System.out.println("Color: " + colors[i]);
// }
// int[] scores = new int[3];
// scores[0] = 85;
// scores[1] = 90;
// scores[2] = 78;
// System.out.println("Total: " + (scores[0] + scores[1] + scores[2]));
// </code>
//                 </pre>
//             </div>
//         </div>
//     </div>
//     <!-- Unit 7: ArrayLists -->
//     <div class="unit-card">
//         <div class="unit-title">Unit 7: ArrayLists</div>
//         <div class="unit-content">
//             ArrayLists are dynamic arrays that can grow and shrink in size. They are part of Java’s `Collections` framework.
//             <div class="code-snippet">
//                 <pre class="code">
// <code>ArrayList&lt;Integer&gt; numbers = new ArrayList&lt;&gt;();
// numbers.add(10);
// numbers.add(20);
// System.out.println("Sum: " + (numbers.get(0) + numbers.get(1)));
//
// ArrayList&lt;String&gt; names = new ArrayList&lt;&gt;();
// names.add("Alice");
// names.add("Bob");
// names.remove("Alice");
// System.out.println("Remaining Names: " + names);
// </code>
//                 </pre>
//             </div>
//         </div>
//     </div>
//     <!-- Unit 8: 2D Arrays -->
//     <div class="unit-card">
//         <div class="unit-title">Unit 8: 2D Arrays</div>
//         <div class="unit-content">
//             This unit extends the concept of arrays to two dimensions, like a table of rows and columns.
//             <div class="code-snippet">
//                 <pre class="code">
// <code>int[][] grid = new int[2][2];
// grid[0][0] = 1;
// grid[0][1] = 2;
// grid[1][0] = 3;
// grid[1][1] = 4;
// System.out.println("Grid Value: " + grid[1][1]);
//
// String[][] board = {
//   {"Rook", "Knight"},
//   {"Bishop", "Queen"}
// };
// System.out.println("Piece at (1,0): " + board[1][0]);
// </code>
//                 </pre>
//             </div>
//         </div>
//     </div>
// </div>
//
// <!-- Include the following CSS and JavaScript for animations and interactivity -->
// <style>
//     /* Code Snippet Styling */
//     .code-snippet {
//         background: #272822;
//         color: #f8f8f2;
//         padding: 15px;
//         border-radius: 6px;
//         margin-top: 10px;
//         overflow: auto;
//         max-height: 250px; /* Increased height to accommodate longer examples */
//     }
//
//     .code {
//         font-family: 'Courier New', Courier, monospace;
//         white-space: pre-wrap;
//         margin: 0;
//     }
//
//     /* Typewriter Animation */
//     .typewriter .code {
//         border-right: 2px solid #f8f8f2;
//         white-space: nowrap;
//         overflow: hidden;
//         width: 0;
//         animation: typing 4s steps(60, end) forwards, blink 0.5s step-end infinite alternate;
//     }
//
//     @keyframes typing {
//         from { width: 0; }
//         to { width: 100%; }
//     }
//
//     @keyframes blink {
//         from { border-color: transparent; }
//         to { border-color: #f8f8f2; }
//     }
// </style>
//
// <script>
//     // Apply typewriter animation to each code block on page load
//     window.onload = function() {
//         var codeBlocks = document.querySelectorAll('.code-snippet .code');
//         codeBlocks.forEach((codeBlock) => {
//             codeBlock.classList.add('typewriter');
//         });
//     };
// </script>

// %% [markdown]
// <html lang="en">
// <head>
//     <meta charset="UTF-8">
//     <meta name="viewport" content="width=device-width, initial-scale=1.0">
//     <title>Java Programming - Advanced Concepts NOTES SPECFIC</title>
//     <style>
//         body {
//             font-family: 'Arial', sans-serif;
//             background-color: #f4f4f4;
//             margin: 0;
//             padding: 0;
//         }
//         header {
//             background-color: #3b5998;
//             color: white;
//             text-align: center;
//             padding: 1.5em 0;
//         }
//         .container {
//             margin: 2em auto;
//             width: 80%;
//         }
//         .unit-card {
//             background: #ffffff;
//             border-radius: 8px;
//             margin-bottom: 1.5em;
//             padding: 1.5em;
//             box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
//             transition: transform 0.3s ease-in-out;
//         }
//         .unit-card:hover {
//             transform: scale(1.03);
//         }
//         .unit-title {
//             font-size: 1.8em;
//             color: #333;
//             margin-bottom: 0.5em;
//         }
//         .unit-content {
//             font-size: 1.1em;
//             color: #666;
//             line-height: 1.6;
//             margin-bottom: 1em;
//         }
//         .code-snippet {
//             background: #1e1e1e;
//             color: #dcdcdc;
//             padding: 15px;
//             border-radius: 6px;
//             margin-top: 10px;
//             overflow: auto;
//             max-height: 300px;
//             white-space: pre-wrap;
//             box-shadow: inset 0 0 10px rgba(0, 0, 0, 0.1);
//             transition: max-height 0.5s ease-out;
//         }
//         .code {
//             font-family: 'Courier New', Courier, monospace;
//             white-space: pre-wrap;
//             margin: 0;
//         }
//         footer {
//             background: #3b5998;
//             color: white;
//             text-align: center;
//             padding: 1em 0;
//             margin-top: 2em;
//         }
//         .tooltip {
//             position: relative;
//             display: inline-block;
//             cursor: pointer;
//             color: #3b5998;
//             font-weight: bold;
//         }
//         .tooltip .tooltiptext {
//             visibility: hidden;
//             width: 250px;
//             background-color: #333;
//             color: #fff;
//             text-align: center;
//             border-radius: 5px;
//             padding: 5px 0;
//             position: absolute;
//             z-index: 1;
//             bottom: 125%;
//             left: 50%;
//             margin-left: -125px;
//             opacity: 0;
//             transition: opacity 0.3s ease-in-out;
//         }
//         .tooltip:hover .tooltiptext {
//             visibility: visible;
//             opacity: 1;
//         }
//     </style>
// </head>
// <body>
//     <header>
//         <h1>Java Programming - Advanced Concepts</h1>
//         <p>Interactive Guide to Object-Oriented Concepts: Objects, Classes, and Inheritance</p>
//     </header>
//     <div class="container">
//         <!-- Unit 2: Using Objects -->
//         <div class="unit-card">
//             <div class="unit-title">Unit 2: Using Objects</div>
//             <div class="unit-content">
//                 This unit focuses on creating objects, using constructors, and calling methods in Java. Learn how to instantiate objects and use their properties.
//                 <div class="tooltip">Key Concepts
//                     <span class="tooltiptext">Covers instantiation, constructors, and method invocation.</span>
//                 </div>
//             </div>
//             <div class="code-snippet">
//                 <pre class="code"><code>// Object instantiation
// Car myCar = new Car("Toyota", "Camry", 2020);
// myCar.startEngine(); // Calling a method on the object
// // Example with a constructor
// Person student = new Person("John Doe", 21);
// System.out.println(student.getName()); // Output: John Doe
// // Updating object properties
// student.setName("Jane Doe");
// System.out.println(student.getName()); // Output: Jane Doe
// </code></pre>
//             </div>
//         </div>
//         <!-- Unit 5: Writing Classes -->
//         <div class="unit-card">
//             <div class="unit-title">Unit 5: Writing Classes</div>
//             <div class="unit-content">
//                 This unit covers how to create custom classes, define properties, and apply encapsulation using getters and setters.
//                 <div class="tooltip">Key Concepts
//                     <span class="tooltiptext">Class definition, encapsulation, and constructors.</span>
//                 </div>
//             </div>
//             <div class="code-snippet">
//                 <pre class="code"><code>// Custom class with encapsulation
// public class BankAccount {
//     private double balance; // Encapsulated property
//     // Constructor
//     public BankAccount(double initialBalance) {
//         this.balance = initialBalance;
//     }
//     // Getter for balance
//     public double getBalance() {
//         return balance;
//     }
//     // Setter for balance
//     public void deposit(double amount) {
//         balance += amount;
//     }
// }
// // Using the class
// BankAccount myAccount = new BankAccount(1000);
// myAccount.deposit(500);
// System.out.println(myAccount.getBalance()); // Output: 1500
// </code></pre>
//             </div>
//         </div>
//         <!-- Unit 9: Inheritance -->
//         <div class="unit-card">
//             <div class="unit-title">Unit 9: Inheritance</div>
//             <div class="unit-content">
//                 Inheritance allows a class to inherit properties and behaviors from another class. Understand how to use `extends` to create subclasses.
//                 <div class="tooltip">Key Concepts
//                     <span class="tooltiptext">Inheritance, method overriding, and polymorphism.</span>
//                 </div>
//             </div>
//             <div class="code-snippet">
//                 <pre class="code"><code>// Base class
// class Animal {
//     public void eat() {
//         System.out.println("Eating...");
//     }
// }
// // Subclass
// class Dog extends Animal {
//     public void bark() {
//         System.out.println("Barking...");
//     }
//
//     // Overriding the eat method
//     @Override
//     public void eat() {
//         System.out.println("Dog is eating...");
//     }
// }
//
// // Using inheritance
// Dog myDog = new Dog();
// myDog.eat(); // Output: Dog is eating...
// myDog.bark(); // Output: Barking...
// </code></pre>
//             </div>
//         </div>
//     </div>
//
//     <footer>
//         <p>&copy; 2024 Java Curriculum Overview</p>
//     </footer>
//
//     <script>
//         // Apply animations to code snippets on load
//         window.onload = function() {
//             var codeBlocks = document.querySelectorAll('.code-snippet .code');
//             codeBlocks.forEach((codeBlock) => {
//                 codeBlock.classList.add('typewriter');
//             });
//         };
//     </script>
// </body>
// </html>

// %% [markdown]
// ![image](https://github.com/user-attachments/assets/a641be13-7445-4def-8f2e-b7e91b5a7b55)
//
// ![image](https://github.com/user-attachments/assets/3dcbef6b-b18b-4772-9044-e3f810c0d4dd)
// ![image](https://github.com/user-attachments/assets/9ccc7a2d-b78d-4033-ac23-21dcf021a9c3)
//
//
// Polymorphism & Superclasses
// Polymorphism = Using the same method name but having different behavior based on the object type.
//
// Example in Code:
// Parent Class: Car has a displayInfo() method.
// Subclasses: SportsCar, SUV, Truck override displayInfo().
// Each subclass adds its own details when displayInfo() is called.
// Why Polymorphism?
// Lets subclasses act differently while sharing the same method name.
// You can treat a SportsCar, SUV, or Truck as just a Car but still get the specific behavior of each type.
// super Keyword
// Used in constructors to call the parent class and set shared values (make, model, etc.).

// %%
import java.util.Scanner;
class Car {
    String make;
    String model;
    int year;
    public Car(String make, String model, int year) {
        this.make = make;
        this.model = model;
        this.year = year;
    }
    public void displayInfo() {
        System.out.println("Car Details:");
        System.out.println("Make: " + make);
        System.out.println("Model: " + model);
        System.out.println("Year: " + year);
    }
}
class SportsCar extends Car {
    String topSpeed;
    public SportsCar(String make, String model, int year, String topSpeed) {
        super(make, model, year); 
        this.topSpeed = topSpeed;
    }

    @Override
    public void displayInfo() {
        super.displayInfo();
        System.out.println("Type: Sports Car");
        System.out.println("Top Speed: " + topSpeed);
    }
}

// Subclass representing an SUV
class SUV extends Car {
    boolean isFourWheelDrive;

    // Constructor using the super keyword to call the parent constructor
    public SUV(String make, String model, int year, boolean isFourWheelDrive) {
        super(make, model, year);  // Call the base Car constructor
        this.isFourWheelDrive = isFourWheelDrive;
    }

    @Override
    public void displayInfo() {
        super.displayInfo();
        System.out.println("Type: SUV");
        System.out.println("Four-Wheel Drive: " + (isFourWheelDrive ? "Yes" : "No"));
    }
}

// Subclass representing a Truck
class Truck extends Car {
    double towingCapacity;

    // Constructor using the super keyword to call the parent constructor
    public Truck(String make, String model, int year, double towingCapacity) {
        super(make, model, year);  // Call the base Car constructor
        this.towingCapacity = towingCapacity;
    }

    @Override
    public void displayInfo() {
        super.displayInfo();
        System.out.println("Type: Truck");
        System.out.println("Towing Capacity: " + towingCapacity + " tons");
    }
}

public class CarGame {
    public static void main(String[] args) {
        Scanner input = new Scanner(System.in);
        boolean exit = false;

        while (!exit) {
            System.out.println("\n--- Welcome to the Car Game! ---");
            System.out.println("Choose the type of vehicle you want to create:");
            System.out.println("1. Sports Car");
            System.out.println("2. SUV");
            System.out.println("3. Truck");
            System.out.println("4. Exit");
            System.out.print("Enter your choice: ");
            
            int choice = input.nextInt();
            input.nextLine();  // Clear the buffer
            
            switch (choice) {
                case 1:  // Create a Sports Car
                    System.out.print("Enter the make of the car: ");
                    String sportsMake = input.nextLine();
                    System.out.print("Enter the model of the car: ");
                    String sportsModel = input.nextLine();
                    System.out.print("Enter the year of the car: ");
                    int sportsYear = input.nextInt();
                    input.nextLine();  // Clear the buffer
                    System.out.print("Enter the top speed of the car (e.g., 200 mph): ");
                    String topSpeed = input.nextLine();
                    
                    SportsCar sportsCar = new SportsCar(sportsMake, sportsModel, sportsYear, topSpeed);
                    System.out.println("\n--- Your Sports Car ---");
                    sportsCar.displayInfo();
                    break;
                    
                case 2:  // Create an SUV
                    System.out.print("Enter the make of the SUV: ");
                    String suvMake = input.nextLine();
                    System.out.print("Enter the model of the SUV: ");
                    String suvModel = input.nextLine();
                    System.out.print("Enter the year of the SUV: ");
                    int suvYear = input.nextInt();
                    System.out.print("Does the SUV have four-wheel drive? (true/false): ");
                    boolean isFourWheelDrive = input.nextBoolean();
                    
                    SUV suv = new SUV(suvMake, suvModel, suvYear, isFourWheelDrive);
                    System.out.println("\n--- Your SUV ---");
                    suv.displayInfo();
                    break;
                    
                case 3:  // Create a Truck
                    System.out.print("Enter the make of the truck: ");
                    String truckMake = input.nextLine();
                    System.out.print("Enter the model of the truck: ");
                    String truckModel = input.nextLine();
                    System.out.print("Enter the year of the truck: ");
                    int truckYear = input.nextInt();
                    System.out.print("Enter the towing capacity in tons (e.g., 5.5): ");
                    double towingCapacity = input.nextDouble();
                    
                    Truck truck = new Truck(truckMake, truckModel, truckYear, towingCapacity);
                    System.out.println("\n--- Your Truck ---");
                    truck.displayInfo();
                    break;
                    
                case 4:  // Exit the game
                    exit = true;
                    System.out.println("Exiting the Car Game. Goodbye!");
                    break;
                    
                default:
                    System.out.println("Invalid choice. Please try again.");
            }
        }
        input.close();
    }
}
CarGame.main(null);
// Out:
// --- Welcome to the Car Game! ---
// Choose the type of vehicle you want to create:
// 1. Sports Car
// 2. SUV
// 3. Truck
// 4. Exit
// Enter your choice: Enter the make of the car: Enter the model of the car: Enter the year of the car: Enter the top speed of the car (e.g., 200 mph):
// --- Your Sports Car ---
// Car Details:
// Make: Mustang
// Model: Ferrari
// Year: 2018
// Type: Sports Car
// Top Speed: 200
//
// --- Welcome to the Car Game! ---
// Choose the type of vehicle you want to create:
// 1. Sports Car
// 2. SUV
// 3. Truck
// 4. Exit
// Enter your choice: Exiting the Car Game. Goodbye!

// %% [markdown]
// ![image](https://github.com/user-attachments/assets/83d46145-cd08-4855-bdd5-969eaf30c1c0)
//
//
// ![image](https://github.com/user-attachments/assets/cd8d3abf-4737-4818-9674-a9c78469aae5)
