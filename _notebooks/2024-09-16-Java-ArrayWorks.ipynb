// %% [markdown]
// ---
// layout: post
// title: TEAMTEACH
// description:  HACKS
// type: ccc
// toc: false
// courses: {csa: {week: 2}}
// ---

// %% [markdown]
// Array: Imagine a row of lockers, where each locker is labeled with an index, and inside each locker is a value.
// Index: The number above each locker that helps you find the exact item you're looking for.
// Accessing: Walk up to the locker, open it, and see what’s inside.
// Updating: Replace the item in the locker with a new one.
// Dynamic Growth: New lockers can be added to the end of the row if more space is needed.
// Looping: Walking down the row, opening each locker one by one, and looking inside.
// Multi-dimensional arrays: Rows and columns of lockers in a grid, where you access items by specifying both the row and column.
// Empty lockers: Sometimes a locker is there, but it’s empty, representing null or undefined.

// %%
public class MaxMinInArray {

    public static void findMaxAndMin(int[] array) {
       
        if (array == null || array.length == 0) {
            System.out.println("Array is empty");
            return;
        }

        int max = array[0];
        int min = array[0];

        
        for (int i = 1; i < array.length; i++) {
            
            if (array[i] > max) {
                max = array[i];  
            }
            if (array[i] < min) {
                min = array[i];  
            }
        }

        System.out.println("Maximum value: " + max);
        System.out.println("Minimum value: " + min);
    }

    public static void main(String[] args) {
     
        int[] array = {3, 5, 7, 2, 8, -1, 4, 10, 12};

        
        findMaxAndMin(array);
    }
}
MaxMinInArray.main(null)
// Out:
// Maximum value: 12
// Minimum value: -1

// %% [markdown]
// <!DOCTYPE html>
// <html lang="en">
// <head>
//     <meta charset="UTF-8">
//     <meta name="viewport" content="width=device-width, initial-scale=1.0">
//     <title>How to Improve Code</title>
// </head>
// <body>
//     <h1>Improving Code</h1>
//     <p><strong>How can I make this code better?</strong></p>
// </body>
// </html>

// %%
public class MaxMinInArray {

    public static void findMaxAndMin(int[] array) {

        if (array == null || array.length == 0) {
            System.out.println("Array is empty");
            return;
        }

        int max, min;
        int startIndex;

        
        if (array.length % 2 == 0) {
            
            if (array[0] > array[1]) {
                max = array[0];
                min = array[1];
            } else {
                max = array[1];
                min = array[0];
            }
            startIndex = 2; 
        } else {
            
            max = min = array[0];
            startIndex = 1; 
        }

        
        for (int i = startIndex; i < array.length - 1; i += 2) {
            int localMax, localMin;

            
            if (array[i] > array[i + 1]) {
                localMax = array[i];
                localMin = array[i + 1];
            } else {
                localMax = array[i + 1];
                localMin = array[i];
            }

            
            if (localMax > max) {
                max = localMax;
            }
            if (localMin < min) {
                min = localMin;
            }
        }

        System.out.println("Maximum value: " + max);
        System.out.println("Minimum value: " + min);
    }

    public static void main(String[] args) {

        int[] array = {3, 5, 7, 2, 8, -1, 4, 10, 12};

        findMaxAndMin(array);
    }
}
MaxMinInArray.main(null)
// Out:
// Maximum value: 12
// Minimum value: -1

// %%
public class AverageCalculator {

    public static double calculateAverageNormalFor(double[] array) {
        double sum = 0;
        
        
        for (int i = 0; i < array.length; i++) {
            sum += array[i];  
        }
        
       
        return sum / array.length;
    }

    public static void main(String[] args) {
        double[] values = {10.5, 20.3, 30.7, 40.9};
        System.out.println("Average (Normal For Loop): " + calculateAverageNormalFor(values));
    }
}
AverageCalculator.main(null)
// Out:
// Average (Normal For Loop): 25.6

// %%
public class AverageCalculator1 {

    public static double calculateAverageEnhancedFor(double[] array) {
        double sum = 0;
 
        for (double value : array) {
            sum += value;
        }
        return sum / array.length;
    }
    public static void main(String[] args) {
        double[] values = {10.5, 20.3, 30.7, 40.9};
        System.out.println("Average (Enhanced For Loop): " + calculateAverageEnhancedFor(values));
    }
}
AverageCalculator1.main(null)
// Out:
// Average (Enhanced For Loop): 25.6

// %%
public class ArrayShifter {

    public static void main(String[] args) {
        int[] numbers = {1, 2, 3, 4, 5};
        
        int[] shifted = new int[numbers.length];
        
        int shift = 8;
        
        for (int index = 0; index < numbers.length; index++) {
            shifted[Math.abs((index + shift) % numbers.length)] = numbers[index];
        }
        numbers = shifted;
        for (int num : numbers) {
            System.out.print(num + " ");
        }
    }
}
ArrayShifter.main(null)
// Out:
// 3 4 5 1 2

// %% [markdown]
// <!DOCTYPE html>
// <html lang="en">
// <head>
//     <meta charset="UTF-8">
//     <meta name="viewport" content="width=device-width, initial-scale=1.0">
//     <title>Question</title>
//     <style>
//         body {
//             font-family: 'Arial', sans-serif;
//             background-color: #f4f4f9;
//             color: #333;
//             margin: 0;
//             padding: 20px;
//         }
//         .container {
//             max-width: 600px;
//             margin: auto;
//             background-color: #fff;
//             padding: 20px;
//             box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
//             border-radius: 10px;
//             text-align: center;
//         }
//         h1 {
//             color: #007BFF;
//         }
//         p {
//             font-size: 20px;
//             font-weight: bold;
//             color: #333;
//         }
//         .btn {
//             display: block;
//             width: fit-content;
//             padding: 10px 20px;
//             margin: 20px auto 0;
//             background-color: #007BFF;
//             color: white;
//             text-align: center;
//             border: none;
//             border-radius: 5px;
//             cursor: pointer;
//         }
//         .btn:hover {
//             background-color: #0056b3;
//         }
//     </style>
// </head>
// <body>
//
// <div class="container">
//     <h1>Question</h1>
//     <p>What's the difference between this code?</p>
//
//     <button class="btn">Find Out</button>
// </div>
//
// </body>
// </html>

// %%
public class WordShifter {  
    public static void main(String[] args) {
        String[] words = {"alpha", "beta", "gamma", "delta"};
        int shiftWord = 2;
        for (int count = 0; count < shiftWord; count++) {
            String temp = words[0];
            for (int index = 0; index < words.length - 1; index++) {
                words[index] = words[index + 1];
            }
            words[words.length - 1] = temp;
        }
        for (String word : words) {
            System.out.print(word + " ");
        }
    }
}
WordShifter.main(null)
// Out:
// gamma delta alpha beta

// %% [markdown]
// <!DOCTYPE html>
// <html lang="en">
// <head>
//     <meta charset="UTF-8">
//     <meta name="viewport" content="width=device-width, initial-scale=1.0">
//     <title>Java Code Request</title>
//     <style>
//         body {
//             font-family: 'Arial', sans-serif;
//             background-color: #f7f9fc;
//             color: #333;
//             margin: 0;
//             padding: 20px;
//         }
//         .container {
//             max-width: 600px;
//             margin: auto;
//             background-color: #fff;
//             padding: 20px;
//             border-radius: 10px;
//             box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
//         }
//         h1 {
//             color: #007BFF;
//             text-align: center;
//         }
//         p {
//             font-size: 18px;
//             text-align: center;
//             margin-bottom: 20px;
//         }
//         .question {
//             font-weight: bold;
//             font-size: 20px;
//             color: #555;
//             text-align: center;
//         }
//         .code-box {
//             background-color: #f4f4f9;
//             padding: 15px;
//             border-left: 5px solid #007BFF;
//             border-radius: 5px;
//             font-family: 'Courier New', monospace;
//             margin-top: 20px;
//         }
//         .btn {
//             display: block;
//             width: fit-content;
//             padding: 10px 20px;
//             margin: 20px auto 0;
//             background-color: #007BFF;
//             color: white;
//             text-align: center;
//             border: none;
//             border-radius: 5px;
//             cursor: pointer;
//         }
//         .btn:hover {
//             background-color: #0056b3;
//         }
//     </style>
// </head>
// <body>
//
// <div class="container">
//     <h1>Java Array Input Parsing</h1>
//     <p class="question">Can you provide me Java code that takes input and parses it into an array in some way, shape, or form?</p>
//
//     <div class="code-box">
//         <p>Example expected:</p>
//         <pre>
// - Parse input into an integer array
// - Parse input into a string array
// - Handle user input with spaces or commas</pre>
//     </div>
//
//     <button class="btn">Submit Your Solution</button>
// </div>
//
// </body>
// </html>

// %% [markdown]
// <!DOCTYPE html>
// <html lang="en">
// <head>
//     <meta charset="UTF-8">
//     <meta name="viewport" content="width=device-width, initial-scale=1.0">
//     <title>Java Input Parsing Question</title>
//     <style>
//         body {
//             font-family: 'Arial', sans-serif;
//             background-color: #f0f2f5;
//             color: #333;
//             padding: 20px;
//         }
//         .container {
//             max-width: 600px;
//             margin: 0 auto;
//             background-color: #fff;
//             padding: 20px;
//             border-radius: 10px;
//             box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
//         }
//         h1 {
//             text-align: center;
//             color: #007BFF;
//         }
//         p {
//             font-size: 18px;
//             text-align: center;
//         }
//         .code-box {
//             display: none;
//             background-color: #f4f4f9;
//             padding: 15px;
//             border-left: 5px solid #007BFF;
//             border-radius: 5px;
//             font-family: 'Courier New', monospace;
//             white-space: pre-wrap;
//             margin-top: 10px;
//         }
//         .btn {
//             display: block;
//             width: fit-content;
//             padding: 10px 20px;
//             margin: 20px auto;
//             background-color: #007BFF;
//             color: white;
//             text-align: center;
//             border: none;
//             border-radius: 5px;
//             cursor: pointer;
//         }
//         .btn:hover {
//             background-color: #0056b3;
//         }
//     </style>
// </head>
// <body>
//
// <div class="container">
//     <h1>Java Code Challenge</h1>
//     <p>Can you provide Java code that takes user input and parses it into an array?</p>
//
//     <button class="btn" onclick="toggleCode()">View Code</button>
//
//     <div class="code-box" id="codeBox">
//         <code>
// import java.util.Scanner;
//
// public class SimpleInputParser {
//
//     public static void main(String[] args) {
//         Scanner scanner = new Scanner(System.in);
//
//         System.out.println("Enter a list of words or numbers separated by spaces or commas:");
//         String input = scanner.nextLine();
//
//         String[] parsedArray = input.split("[,\\s]+");
//         System.out.println("Parsed Array:");
//         for (String element : parsedArray) {
//             System.out.print(element + " ");
//         }
//     }
// }
//         </code>
//     </div>
// </div>
//
// <script>
//     function toggleCode() {
//         var codeBox = document.getElementById("codeBox");
//         if (codeBox.style.display === "none") {
//             codeBox.style.display = "block";
//         } else {
//             codeBox.style.display = "none";
//         }
//     }
// </script>
//
// </body>
// </html>
